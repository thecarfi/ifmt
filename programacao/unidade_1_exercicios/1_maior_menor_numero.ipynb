# %% [markdown]
# # Esse código foi criado para pegar 10 numeros via input e verificar qual o maior e menor número

# %%
numero1 = int(input("Qual o numero 1: ")) 
numero2 = int(input("Qual o numero 2: "))
numero3 = int(input("Qual o numero 3: "))
numero4 = int(input("Qual o numero 4: "))
numero5 = int(input("Qual o numero 5: "))
numero6 = int(input("Qual o numero 6: "))
numero7 = int(input("Qual o numero 7: "))
numero8 = int(input("Qual o numero 8: "))
numero9 = int(input("Qual o numero 9: "))
numero10 = int(input("Qual o numero 10: "))



if numero1 > numero2 and numero1 > numero3 and numero1 > numero4 and numero1 > numero5 and numero1 > numero6 and numero1 > numero7 and numero1 > numero8 and numero1 > numero9 and numero1 > numero10:
    print(f"O maior número é o primeiro número: {numero1}")
if numero1 < numero2 and numero1 < numero3 and numero1 < numero4 and numero1 < numero5 and numero1 < numero6 and numero1 < numero7 and numero1 < numero8 and numero1 < numero9 and numero1 < numero10:
    print(f"O menor número é o primeiro número: {numero1}")

if numero2 > numero1 and numero2 > numero3 and numero2 > numero4 and numero2 > numero5 and numero2 > numero6 and  numero2 > numero7  and numero2 > numero8 and numero2 > numero9 and numero2 > numero10:
    print(f"O maior número é o segundo número: {numero2}")
if numero2 < numero1 and numero2 < numero3 and numero2 < numero4 and numero2 < numero5 and numero2 < numero6 and numero2 < numero7 and numero2 < numero8 and numero2 < numero9 and numero2 < numero10:
    print(f"O menor número é o segundo número: {numero2}")

if numero3 > numero1 and numero3 > numero2 and numero3 > numero4 and numero3 > numero5 and numero3 > numero6 and numero3 > numero7 and numero3 > numero8 and numero3 > numero9 and numero3 > numero10:
    print(f"O maior número é o terceiro número: {numero3}")
if numero3 < numero1 and numero3 < numero2 and numero3 < numero4 and numero3 < numero5 and numero3 < numero6 and numero3 < numero7 and numero3 < numero8 and numero3 < numero9 and numero3 < numero10:
    print(f"O menor número é o terceiro número: {numero3}")

if numero4 > numero1 and numero4 > numero2 and numero4 > numero3 and numero4 > numero5 and numero4 > numero6 and numero4 > numero7 and numero4 > numero8 and numero4 > numero9 and numero4 > numero10:
    print(f"O maior número é o quarto número: {numero4}")
if numero4 < numero1 and numero4 < numero2 and numero4 < numero3 and numero4 < numero5 and numero4 < numero6 and numero4 < numero7 and numero4 < numero8 and numero4 < numero9 and numero4 < numero10:
    print(f"O menor número é o quarto número: {numero4}")



if numero5 > numero1 and numero5 > numero2 and numero5 > numero3 and numero5 > numero4 and numero5 > numero6 and numero5 > numero7 and numero5 > numero8 and numero5 > numero9 and numero5 > numero10:
    print(f"O maior número é o quinto número: {numero5}")
if numero5 < numero1 and numero5 < numero2 and numero5 < numero3 and numero5 < numero4 and numero5 < numero6 and numero5 < numero7 and numero5 < numero8 and numero5 < numero9 and numero5 < numero10:
    print(f"O menor número é o quinto número: {numero5}")

if numero6 > numero1 and numero6 > numero2 and numero6 > numero3 and numero6 > numero4 and numero6 > numero5 and numero6 > numero7 and numero6 > numero8 and numero6 > numero9 and numero6 > numero10:
    print(f"O maior número é o sexto número: {numero6}")
if numero6 < numero1 and numero6 < numero2 and numero6 <numero3 and numero6 <numero4 and numero6 < numero5 and numero6 < numero7 and numero6 < numero8 and numero6 < numero9 and numero6 < numero10:
    print(f"O menor número é o sexto número: {numero6}")

if numero7 > numero1 and numero7 > numero2 and numero7 > numero3 and numero7 > numero4 and numero7 > numero5 and numero7 > numero6 and numero7 > numero8 and numero7 > numero9 and numero7 > numero10:
    print(f"O maior número é o sétimo número: {numero7}")
if numero7 < numero1 and numero7 < numero2 and numero7 < numero3 and numero7 < numero4 and numero7 < numero5 and numero7 < numero6 and numero7 < numero8 and numero7 < numero9 and numero7 < numero10:
    print(f"O menor número é o sétimo número: {numero7}")

if numero8 > numero1 and numero8 > numero2 and numero8 > numero3 and numero8 > numero4 and numero8 > numero5 and numero8 > numero6 and numero8 > numero7 and numero8 > numero9 and numero8 > numero10:
    print(f"O maior número é o oitavo número: {numero8}")
if numero8 < numero1 and numero8 < numero2 and numero8 < numero3 and numero8 < numero4 and numero8 < numero5 and numero8 < numero6 and numero8 < numero7 and numero8 < numero9  and  numero8 < numero10:
    print(f"O menor número é o oitavo número: {numero8}")

if numero9 > numero1 and numero9 > numero2 and numero9 > numero3 and numero9 > numero4 and numero9 > numero5 and numero9 > numero6 and numero9 > numero7 and numero9 > numero8  and  numero9 > numero10:
    print(f"O maior número é o nono número: {numero9}")
if numero9 < numero1 and numero9< numero2 and numero9 < numero3 and numero9 < numero4 and numero9 < numero5 and numero9 < numero6 and numero9 < numero7 and numero9 < numero8 and numero9 < numero9:
    print(f"O menor número é o nono número: {numero9}")

if numero10 > numero1 and numero10 > numero2 and numero10 > numero3 and numero10 > numero4 and numero10 > numero5 and numero10 > numero6 and numero10 > numero7 and numero10 > numero8 and numero10 > numero9:
    print(f"O maior número é o décimo número: {numero10}")
if numero10 < numero1 and numero10 < numero2 and numero10 < numero3 and numero10 < numero4 and numero10 < numero5 and numero10 < numero6 and numero10 < numero7 and numero10 < numero8 and numero10 < numero9:
    print(f"O menor número é o décimo número: {numero10}")
# Out:
# O maior número é o segundo número: 123
# O menor número é o terceiro número: 1
