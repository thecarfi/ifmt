# %% [markdown]
# #Esse código foi desenvolvido para pegar a número inverso do que está sendo passado no input()

# %%
i = int(input("Qual o número a ser invertido: "))

j = 0
modulo = ""
while i != 0:
    modulo += str(i % 10)
    print(modulo)
    i = i // 10
# Out:
# 6
# 65
# 654
