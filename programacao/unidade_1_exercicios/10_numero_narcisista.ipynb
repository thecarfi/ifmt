# %%
#Esse código foi desenvolvido para verificar se um número é narcisista ou não.

#O número narcisista é um número em que se a gente pegar cada algarismo dele, elevar a quantidade de algarismo que ele tem, 
# o resultado será ele mesmo

# %%
x = int(input("Qual o número: "))
j = x
QtdeAlgarismo = 0
iterador = x
resto = x
resultado = 0


#Pega a quantidade de algarismo do número
while iterador > 0:
    iterador = iterador // 10
    QtdeAlgarismo += 1


#pega cada número para pode multiplicar depois
while x > 0:

    print(f"resto: {resto}")
    resto = x % 10
    x = x // 10
    print(resto)
    resultado += resto ** QtdeAlgarismo


if resultado == j:
    print("O número informado é narcisista")
else:
    print("O número informado NÃO é narcisista.")
# Out:
# resto: 1634
# 4
# resto: 4
# 3
# resto: 3
# 6
# resto: 6
# 1
# resultado: 1634
# x: 1634
