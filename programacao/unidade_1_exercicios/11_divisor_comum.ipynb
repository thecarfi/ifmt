# %% [markdown]
# #esse código foi desenvolvido para listar quais os divisores comum de dois números.

# %%
x = int(input("Digite o primeiro número: "))
y = int(input("Digite o segundo número: "))


while x > 0 and y > 0:
    print("a")
